# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_granular = pd.read_csv(r"\\babyserverdw5\Digital pathology image lib\_Image libraries for training\2023-05-09 Published HE Nuclei Datasets\StarDist Training\scores\coarse_tune_granular.csv")
df_coarse = pd.read_csv(r"\\babyserverdw5\Digital pathology image lib\_Image libraries for training\2023-05-09 Published HE Nuclei Datasets\StarDist Training\scores\coarse_tune_summary.csv")

# %%
df = df_coarse[df_coarse['Test Set'] == 'MoNuSeg']
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.boxplot(x=df['Epoch'], y=df['mAP'], hue=df['LR'], ax=axes[0])
sns.boxplot(x=df['Epoch'], y=df['mAP'], hue=df['BS'], ax=axes[1])
plt.show()

# %%
df_granular = pd.read_csv(r"\\babyserverdw5\Digital pathology image lib\_Image libraries for training\2023-05-09 Published HE Nuclei Datasets\StarDist Training\scores\fine_tune_granular.csv")
df_coarse = pd.read_csv(r"\\babyserverdw5\Digital pathology image lib\_Image libraries for training\2023-05-09 Published HE Nuclei Datasets\StarDist Training\scores\fine_tune_summary.csv")

# %%
df = df_coarse[df_coarse['Test Set'] == 'MoNuSeg']
sns.boxplot(x=df['Epoch'], y=df['mAP'], hue=df['LR'])
plt.show()

# %%
df_55 = df[df['LR'] == 5.5e-06]
df_55 = df_55[~((df_55['Epoch'] % 25 == 0) & (df_55['Epoch'] % 50 != 0))]
df_55.head()
# Out:
#     Train Set Train Fold        LR  BS  Epoch Test Set
# 592   MoNuSeg     fold_1  0.000005   4      0  MoNuSeg  \
# 593   MoNuSeg     fold_1  0.000005   4      0  MoNuSeg
# 594   MoNuSeg     fold_1  0.000005   4      0  MoNuSeg
# 595   MoNuSeg     fold_1  0.000005   4      0  MoNuSeg
# 596   MoNuSeg     fold_1  0.000005   4      0  MoNuSeg
#
#                        Image       IoU       mAP
# 592  TCGA-2Z-A9J9-01A-01-TS1  0.486966  0.267660
# 593  TCGA-38-6178-01Z-00-DX1  0.489569  0.142965
# 594  TCGA-44-2665-01B-06-BS6  0.406944  0.254924
# 595  TCGA-50-5931-01Z-00-DX1  0.333040  0.154352
# 596  TCGA-AR-A1AS-01Z-00-DX1  0.515514  0.357547

# %%
df_granular = pd.read_csv(r"\\babyserverdw5\Digital pathology image lib\_Image libraries for training\2023-05-09 Published HE Nuclei Datasets\StarDist Training\scores\finer_tune_granular.csv")
df_coarse = pd.read_csv(r"\\babyserverdw5\Digital pathology image lib\_Image libraries for training\2023-05-09 Published HE Nuclei Datasets\StarDist Training\scores\finer_tune_summary.csv")

# %%
df = df_coarse[df_coarse['Test Set'] == 'MoNuSeg']
df = pd.concat([df, df_55], ignore_index=True, axis=0)
df.tail()
# Out:
#     Train Set Train Fold        LR  BS  Epoch Test Set
# 203   MoNuSeg     fold_1  0.000005   4    200  MoNuSeg  \
# 204   MoNuSeg     fold_1  0.000005   4    200  MoNuSeg
# 205   MoNuSeg     fold_1  0.000005   4    200  MoNuSeg
# 206   MoNuSeg     fold_1  0.000005   4    200  MoNuSeg
# 207   MoNuSeg     fold_1  0.000005   4    200  MoNuSeg
#
#                        Image       IoU       mAP
# 203  TCGA-50-5931-01Z-00-DX1  0.574814  0.184060
# 204  TCGA-AR-A1AS-01Z-00-DX1  0.661511  0.383043
# 205  TCGA-F9-A8NY-01Z-00-DX1  0.683633  0.378436
# 206  TCGA-G9-6363-01Z-00-DX1  0.659411  0.379382
# 207  TCGA-GL-6846-01A-01-BS1  0.679814  0.472388

# %%
sns.boxplot(x=df['Epoch'], y=df['mAP'], hue=df['LR'])
plt.show()
